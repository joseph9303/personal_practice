# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

# %%
data1 = pd.read_csv('D:\\ref\\cropped\\1404_1.csv')
data2 = pd.read_csv('D:\\ref\\cropped\\1404_2.csv')
data3 = pd.read_csv('D:\\ref\\cropped\\1404_3.csv')
data4 = pd.read_csv('D:\\ref\\cropped\\1404_4.csv')
data5 = pd.read_csv('D:\\ref\\cropped\\1404_5.csv')

# %%
data1.head(10)
# Out:
#             ; Number of ROIs: 1 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  ; File Dimension: 960 x 2131        NaN        NaN        NaN        NaN
# 1                             ;        NaN        NaN        NaN        NaN
# 2            ; ROI name: ROI #9        NaN        NaN        NaN        NaN
# 3         ; ROI rgb value: {128          0         0}        NaN        NaN
# 4             ; ROI npts: 10000        NaN        NaN        NaN        NaN
# 5                             ;        NaN        NaN        NaN        NaN
# 6                      ; File X     File Y         B1         B2         B3
# 7                             ;        NaN        NaN        NaN        NaN
# 8                           179        968     0.1671   0.158336   0.150336
# 9                           180        968   0.155288   0.151224   0.142281
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 185  \
# ...

# %%
data1 = data1.drop([data1.index[0],data1.index[1],data1.index[2],data1.index[3],data1.index[4],data1.index[5],data1.index[7]])
data2 = data2.drop([data2.index[0],data2.index[1],data2.index[2],data2.index[3],data2.index[4],data2.index[5],data2.index[7]])
data3 = data3.drop([data3.index[0],data3.index[1],data3.index[2],data3.index[3],data3.index[4],data3.index[5],data3.index[7]])
data4 = data4.drop([data4.index[0],data4.index[1],data4.index[2],data4.index[3],data4.index[4],data4.index[5],data4.index[7]])
data5 = data5.drop([data5.index[0],data5.index[1],data5.index[2],data5.index[3],data5.index[4],data5.index[5],data5.index[7]])

# %%
data1.head()
# Out:
#    ; Number of ROIs: 1 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 6             ; File X     File Y         B1         B2         B3         B4
# 8                  179        968     0.1671   0.158336   0.150336   0.141664
# 9                  180        968   0.155288   0.151224   0.142281   0.135607
# 10                 181        968   0.108556   0.109884   0.108971   0.108768
# 11                 182        968   0.123729   0.120519   0.119786   0.118482
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 185 Unnamed: 186  \
# 6          B5         B6         B7         B8  ...        LUREX      VISCOSE
# 8    0.135733   0.131822   0.120786   0.115673  ...            0            0
# 9    0.130252   0.128117   0.117608   0.112588  ...            0            0
# 10   0.110072   0.110441   0.109839   0.109599  ...            0            0
# 11   0.117005   0.114545   0.110343   0.101794  ...            0            0
#
# ...

# %%
data1.drop("; Number of ROIs: 1", axis = 1, inplace = True)
data2.drop("; Number of ROIs: 1", axis = 1, inplace = True)
data3.drop("; Number of ROIs: 1", axis = 1, inplace = True)
data4.drop("; Number of ROIs: 1", axis = 1, inplace = True)
data5.drop("; Number of ROIs: 1", axis = 1, inplace = True)

# %%
data1.drop("Unnamed: 1", axis = 1, inplace = True)
data2.drop("Unnamed: 1", axis = 1, inplace = True)
data3.drop("Unnamed: 1", axis = 1, inplace = True)
data4.drop("Unnamed: 1", axis = 1, inplace = True)
data5.drop("Unnamed: 1", axis = 1, inplace = True)

# %%
data3.head()
# Out:
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 6          B1         B2         B3         B4         B5         B6
# 8    0.163855   0.157563   0.150414   0.149187   0.145909   0.143476
# 9    0.152991   0.150963   0.150592   0.144827   0.142612   0.138305
# 10   0.159204   0.151678   0.149761   0.144768   0.141807     0.1392
# 11   0.148729   0.145889   0.143109   0.139311   0.135805    0.13493
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  ... Unnamed: 185  \
# 6          B7         B8          B9         B10  ...        LUREX
# 8    0.130609    0.12425    0.122259    0.122464  ...            0
# 9    0.129156   0.120324     0.11668    0.117016  ...            0
# 10   0.129972   0.127363    0.121212    0.115829  ...            0
# 11   0.132438   0.128199    0.122639    0.117786  ...            0
#
#    Unnamed: 186 Unnamed: 187 Unnamed: 188 Unnamed: 189 Unnamed: 190  \
# 6       VISCOSE       TENCEL        CUPRO  CVC 60%/40%       BAMBOO
# ...

# %%
header1 = data1.iloc[0]
data1 = data1[1:]
data1 = data1.rename(columns = header1)
header2 = data2.iloc[0]
data2 = data2[1:]
data2 = data2.rename(columns = header2)
header3 = data3.iloc[0]
data3 = data3[1:]
data3 = data3.rename(columns = header3)
header4 = data4.iloc[0]
data4 = data4[1:]
data4 = data4.rename(columns = header4)
header5 = data5.iloc[0]
data5 = data5[1:]
data5 = data5.rename(columns = header5)

# %%
data5
# Out:
#              B1        B2        B3        B4        B5        B6        B7  \
# 8      0.126741  0.123709  0.126709  0.125112   0.12369  0.120152  0.118482
# 9      0.137995  0.135679  0.130031  0.129267  0.125178  0.122984  0.124274
# 10     0.126179  0.123711   0.12196  0.117065  0.113163  0.111218  0.101048
# 11     0.133358  0.127798  0.124358  0.120558  0.118628  0.114057  0.105534
# 12     0.129852  0.123235  0.113535  0.110153  0.105547  0.103294  0.097113
# 13     0.155621  0.141033  0.136128  0.130334  0.125546  0.122788  0.113794
# 14     0.125926  0.120875   0.11703  0.113026  0.112611  0.110545  0.106546
# 15     0.129164  0.128589  0.126347   0.12221  0.120272  0.116757   0.10765
# 16     0.128972  0.127697  0.125595  0.124036  0.120056  0.120274  0.118908
# 17     0.110035   0.10766   0.10499  0.106256  0.105946  0.104952  0.098722
# 18     0.135725  0.134083  0.129004  0.122423  0.120132   0.11782  0.108578
# ...

# %%
data = pd.concat([data1, data2, data3, data4, data5],axis=0, ignore_index = True)

# %%
data.shape
# Out:
# (50000, 193)

# %%
data
# Out:
#              B1        B2        B3        B4        B5        B6        B7  \
# 0        0.1671  0.158336  0.150336  0.141664  0.135733  0.131822  0.120786
# 1      0.155288  0.151224  0.142281  0.135607  0.130252  0.128117  0.117608
# 2      0.108556  0.109884  0.108971  0.108768  0.110072  0.110441  0.109839
# 3      0.123729  0.120519  0.119786  0.118482  0.117005  0.114545  0.110343
# 4      0.157793  0.142845   0.13716  0.129063  0.125106  0.121023  0.109243
# 5      0.133959  0.123146  0.119653  0.116685   0.11277   0.11081  0.106681
# 6       0.14046  0.135114  0.128424  0.124152  0.120585  0.119002  0.111573
# 7       0.11072  0.106186  0.107252  0.105462  0.105677  0.104198   0.10544
# 8      0.141105  0.138323  0.133624   0.13027  0.127924  0.125529  0.111624
# 9      0.113833  0.112471  0.112192  0.108152  0.105932  0.103141  0.104922
# 10     0.117268  0.114602  0.111539  0.107445  0.104135  0.100713  0.095592
# ...

# %%
data.to_csv('1404.csv', header=True)
